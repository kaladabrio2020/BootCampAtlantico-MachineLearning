# %%
import cv2
import matplotlib.pyplot as plt

# %%
path  = cv2.imread('imagens/img-raiox/Sindrome-de-Osgood-Schlatter-3.jpg')
image = cv2.blur(
    src = path ,
    ksize= (5,5) 
)

plt.imshow(
    cv2.cvtColor(image,cv2.COLOR_BGR2GRAY),cmap='Reds'
)
plt.show()
