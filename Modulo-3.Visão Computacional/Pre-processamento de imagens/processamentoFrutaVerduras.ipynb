# %%
import cv2 
import matplotlib.pyplot as plt

# %%
path  = cv2.imread('imagens/img-frutas&verduras/Melancia-Crimson-Sweet-Extra.jpg')
image = cv2.cvtColor(path,cv2.COLOR_BGR2RGB)

b , g , r = cv2.split(image)
plt.imshow(g,cmap='gray')
plt.show()
